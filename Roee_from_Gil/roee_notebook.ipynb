# %%
import somadata

# %%
adat = somadata.read_adat('./data/OH2024_014.adat')
# Out:
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "SeqIdVersion"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "Units"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')

# %%
adat.head()
# Out:
# SeqId                                                                                                                                                                                                                                                                                                                                                            10000-28  \
# SeqIdVersion
# SomaId                                                                                                                                                                                                                                                                                                                                                           SL019233
# ...

# %%
dir(adat)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
adat.columns
# Out:
# MultiIndex([('10000-28', '', 'SL019233', ...),
#             ( '10001-7', '', 'SL002564', ...),
#             ('10003-15', '', 'SL019245', ...),
#             ('10006-25', '', 'SL019228', ...),
#             ('10008-43', '', 'SL019234', ...),
#             ('10010-10', '', 'SL014943', ...),
#             ('10011-65', '', 'SL019246', ...),
#             ( '10012-5', '', 'SL014669', ...),
#             ('10013-34', '', 'SL025418', ...),
#             ('10014-31', '', 'SL007803', ...),
#             ...
#             ( '9984-12', '', 'SL019205', ...),
#             ( '9986-14', '', 'SL005356', ...),
#             ( '9987-30', '', 'SL025917', ...),
#             ( '9989-12', '', 'SL019194', ...),
#             ('9991-112', '', 'SL025845', ...),
#             ( '9993-11', '', 'SL019212', ...),
#             ('9994-217', '', 'SL019217', ...),
#             (  '9995-6', '', 'SL013164', ...),
#             ( '9997-12', '', 'SL026026', ...),
#             (  '9999-1', '', 'SL019231', ...)],
# ...

# %%
help(somadata)
# Out:
# Help on package somadata:
#
# NAME
#     somadata
#
# PACKAGE CONTENTS
#     adat
#     annotations
#     base (package)
#     data (package)
#     errors
#     io (package)
#     tools (package)
#
# FILE
#     c:\users\roeeorland\documents\streck-normalization\roee_from_gil\roee_gil_env\lib\site-packages\somadata\__init__.py

# %%
adat.head(5)
# Out:
# SeqId                                                                                                                                                                                                                                                                                                                                                            10000-28  \
# SeqIdVersion
# SomaId                                                                                                                                                                                                                                                                                                                                                           SL019233
# ...

# %%
adat
# Out:
# SeqId                                                                                                                                                                                                                                                                                                                                                                 10000-28  \
# SeqIdVersion
# SomaId                                                                                                                                                                                                                                                                                                                                                                SL019233
# ...

# %%
adat.header_metadata
# Out:
# {'AdatId': 'GID-bdedc176-48a8-4760-96d5-8f07443f780f',
#  '!Version': '1.2',
#  '!AssayType': 'SomaScan',
#  '!AssayVersion': 'v4.1',
#  '!AssayRobot': 'Robot',
#  '!Legal': 'SOMALOGIC - CONFIDENTIAL INFORMATION',
#  '!UseRestriction': 'Research Use Only',
#  '!CreatedBy': 'OncoHost',
#  '!CreatedDate': '2024-10-27 14:38:28.081369',
#  '!ExpDate': '2023-03-10',
#  '!GeneratedBy': 'DataDelve Tools: Normalize1.3.0, Canopy_0.4.1',
#  '!ProcessSteps': 'Raw RFU',
#  '!ProteinEffectiveDate': '2023-02-27 00:00:00',
#  'StudyMatrix': 'EDTA Plasma',
#  'PlateType': 'Prod',
#  'LabLocation': 'OncoHost',
#  'StudyOrganism': 'Human',
#  '!Title': 'OH2024_014',
#  'CalibratorId': '200169',
#  'ReportConfig': {'analysisSteps': [{'includeSampleTypes': ['Calibrator',
#      'QC',
#      'Buffer'],
#     'stepType': 'hybNorm',
#     'referenceSource': 'intraplate'},
#    {'referenceFields': ['SampleId'],
#     'includeSampleTypes': ['Calibrator', 'Buffer'],
#     'stepName': 'medNormInt',
# ...

# %%
adat_df = adat.columns.to_frame()

# %%
adat_df.columns
# Out:
# Index(['SeqId', 'SeqIdVersion', 'SomaId', 'TargetFullName', 'Target',
#        'UniProt', 'EntrezGeneID', 'EntrezGeneSymbol', 'Organism', 'Units',
#        'Type', 'Dilution'],
#       dtype='object')

# %%
adat_df.index
# Out:
# MultiIndex([('10000-28', '', 'SL019233', ...),
#             ( '10001-7', '', 'SL002564', ...),
#             ('10003-15', '', 'SL019245', ...),
#             ('10006-25', '', 'SL019228', ...),
#             ('10008-43', '', 'SL019234', ...),
#             ('10010-10', '', 'SL014943', ...),
#             ('10011-65', '', 'SL019246', ...),
#             ( '10012-5', '', 'SL014669', ...),
#             ('10013-34', '', 'SL025418', ...),
#             ('10014-31', '', 'SL007803', ...),
#             ...
#             ( '9984-12', '', 'SL019205', ...),
#             ( '9986-14', '', 'SL005356', ...),
#             ( '9987-30', '', 'SL025917', ...),
#             ( '9989-12', '', 'SL019194', ...),
#             ('9991-112', '', 'SL025845', ...),
#             ( '9993-11', '', 'SL019212', ...),
#             ('9994-217', '', 'SL019217', ...),
#             (  '9995-6', '', 'SL013164', ...),
#             ( '9997-12', '', 'SL026026', ...),
#             (  '9999-1', '', 'SL019231', ...)],
# ...

# %%
adat_df.reset_index(drop=True, inplace=True)

# %%
adat_df
# Out:
#          SeqId SeqIdVersion    SomaId  \
# 0     10000-28               SL019233
# 1      10001-7               SL002564
# 2     10003-15               SL019245
# 3     10006-25               SL019228
# 4     10008-43               SL019234
# ...        ...          ...       ...
# 7591   9993-11               SL019212
# 7592  9994-217               SL019217
# 7593    9995-6               SL013164
# 7594   9997-12               SL026026
# 7595    9999-1               SL019231
#
#                                          TargetFullName      Target UniProt  \
# 0                                    Beta-crystallin B2       CRBB2  P43320
# 1     RAF proto-oncogene serine/threonine-protein ki...       c-Raf  P04049
# 2                                Zinc finger protein 41       ZNF41  P51814
# 3                   ETS domain-containing protein Elk-1        ELK1  P19419
# 4                 Guanylyl cyclase-activating protein 1       GUC1A  P43080
# ...

# %%
adat_df['SomaId'].value_counts()
# Out:
# SomaId
# SL025418    233
# SL011608     34
# SL000451     11
# SL003198      8
# SL000466      4
#            ...
# SL019212      1
# SL019217      1
# SL013164      1
# SL026026      1
# SL019245      1
# Name: count, Length: 6627, dtype: int64

# %%
import pandas as pd

# %%
somamers = pd.read_excel('./data/SomaScan v4.1_7K_Annotated Content_Oncohost.xlsx', skiprows=8, sheet_name='Annotations')

# %%
somamers
# Out:
#          SeqId    SomaId Target Name  \
# 0     10000-28  SL019233       CRBB2
# 1      10001-7  SL002564       c-Raf
# 2     10003-15  SL019245       ZNF41
# 3     10006-25  SL019228        ELK1
# 4     10008-43  SL019234       GUC1A
# ...        ...       ...         ...
# 7591   9993-11  SL019212       ZN264
# 7592  9994-217  SL019217       ATP4B
# 7593    9995-6  SL013164         DUT
# 7594   9997-12  SL026026  UBXN4:CD 1
# 7595    9999-1  SL019231        IRF6
#
#                                        Target Full Name UniProt ID     Type  \
# 0                                    Beta-crystallin B2     P43320  Protein
# 1     RAF proto-oncogene serine/threonine-protein ki...     P04049  Protein
# 2                                Zinc finger protein 41     P51814  Protein
# 3                   ETS domain-containing protein Elk-1     P19419  Protein
# 4                 Guanylyl cyclase-activating protein 1     P43080  Protein
# ...

# %% [markdown]
# ## Medians

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'name': ['Oscar', 'Schindler', 'Rob', 'Roy', 'Liam'], 'age': [1, 2, 3, 4, 17]})

# %%
df1
# Out:
#         name  age
# 0      Oscar    1
# 1  Schindler    2
# 2        Rob    3
# 3        Roy    4
# 4       Liam   17

# %%
df1.age.median()
# Out:
# np.float64(3.0)

# %%
import numpy as np
def truncate(number, decimals):
    multiplier = 10**decimals
    number = np.floor(number * multiplier)/multiplier
    return number

# %%
truncate(10.1234, 2)
# Out:
# np.float64(10.12)

# %%
x = 3
y = 14
