# %%
import somadata

# %%
def read_adat_file(file_path):
    """
    Reads an ADAT file and returns 2 DataFrames.
    The first DataFrame contains the plate data, and the second DataFrame contains the plate targets.
    Args:
        file_path (str): The path to the ADAT file.
    Returns:
        tuple: A tuple containing two DataFrames (plate_data, plate_targets).
    """
    plate_adat = somadata.read_adat(file_path)
    plate_targets_df = plate_adat.columns.to_frame().reset_index(drop=True) 
    df = plate_adat.reset_index()
    df.columns = ['_'.join(map(str, col)).strip('_') if isinstance(col, tuple) else col
              for col in df.columns]
    df.columns = [column.split('__')[0] for column in df.columns]
    return df, plate_targets_df

# %%
df12, df13 = read_adat_file(r"./data/OH2024_014.adat")
# Out:
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "SeqIdVersion"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "Units"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')

# %%
df12
# Out:
#        PlateId PlateRunDate   ScannerID PlatePosition       SlideId Subarray  \
# 0   OH2024_014   2024-04-03  SG21378706            A1  258633804307        1
# 1   OH2024_014   2024-04-03  SG21378706           A10  258633804316        1
# 2   OH2024_014   2024-04-03  SG21378706           A11  258633804292        1
# 3   OH2024_014   2024-04-03  SG21378706           A12  258633804293        1
# 4   OH2024_014   2024-04-03  SG21378706            A2  258633804308        1
# ..         ...          ...         ...           ...           ...      ...
# 91  OH2024_014   2024-04-03  SG21378706            H5  258633804311        8
# 92  OH2024_014   2024-04-03  SG21378706            H6  258633804312        8
# 93  OH2024_014   2024-04-03  SG21378706            H7  258633804313        8
# 94  OH2024_014   2024-04-03  SG21378706            H8  258633804314        8
# 95  OH2024_014   2024-04-03  SG21378706            H9  258633804315        8
#
#       SampleId  SampleType PercentDilution SampleMatrix  ... 9984-12 9986-14  \
# 0       200169  Calibrator              20               ...  1202.0  6165.7
# 1   2132156351      Sample              20               ...  1847.2  2517.0
# 2   2132281285      Sample              20               ...  1337.1  3449.5
# 3   2132156350      Sample              20               ...  2730.3  8589.5
# 4   2132154726      Sample              20               ...  1307.8  9598.7
# ..         ...         ...             ...          ...  ...     ...     ...
# 91  2132156382      Sample              20               ...  2710.3  7300.7
# 92  2132154712      Sample              20               ...  1196.5  2208.9
# 93  2132155959      Sample              20               ...  1581.2  6010.2
# 94  2132156378      Sample              20               ...  2212.7  6402.6
# 95  2132156335      Sample              20               ...  2493.6  3320.9
#
#    9987-30 9989-12 9991-112 9993-11 9994-217   9995-6  9997-12   9999-1
# 0   1575.5   996.1   2730.1  2481.3   3393.3   3888.4  11088.8   2580.8
# 1   1410.6  1430.1   1790.2  2788.3   5244.1  12829.6  14249.6   9475.5
# 2    905.3  1199.2    835.6  2180.1   3792.3   3082.4  10598.7   2447.9
# 3   2400.0  1946.6   2494.4  4253.0   6926.2   4267.3   8419.4   5668.6
# 4   1022.8  1017.3   1136.9  2237.9   4330.5   5915.0  48394.6  11510.8
# ..     ...     ...      ...     ...      ...      ...      ...      ...
# 91  2397.1  1517.8   2670.2  4342.0   7147.8   6816.5   9090.8   6383.3
# 92   850.0   975.6    836.2  1730.4   2731.7   2499.8  12729.7   2337.8
# 93  1229.5  1517.1   1114.2  3645.5   4195.8  11113.5  30471.0   3624.3
# 94  1850.6  1381.3   2571.1  3510.1   6225.8   6706.5   8943.7   6304.5
# 95  2383.9  1554.9   2836.5  4243.7   8921.5  18352.1  37672.7  18779.7
#
# [96 rows x 7625 columns]

# %%
df13
# Out:
#          SeqId SeqIdVersion    SomaId  \
# 0     10000-28               SL019233
# 1      10001-7               SL002564
# 2     10003-15               SL019245
# 3     10006-25               SL019228
# 4     10008-43               SL019234
# ...        ...          ...       ...
# 7591   9993-11               SL019212
# 7592  9994-217               SL019217
# 7593    9995-6               SL013164
# 7594   9997-12               SL026026
# 7595    9999-1               SL019231
#
#                                          TargetFullName      Target UniProt  \
# 0                                    Beta-crystallin B2       CRBB2  P43320
# 1     RAF proto-oncogene serine/threonine-protein ki...       c-Raf  P04049
# 2                                Zinc finger protein 41       ZNF41  P51814
# 3                   ETS domain-containing protein Elk-1        ELK1  P19419
# 4                 Guanylyl cyclase-activating protein 1       GUC1A  P43080
# ...                                                 ...         ...     ...
# 7591                            Zinc finger protein 264       ZN264  O43296
# 7592         Potassium-transporting ATPase subunit beta       ATP4B  P51164
# 7593  Deoxyuridine 5'-triphosphate nucleotidohydrola...         DUT  P33316
# 7594  UBX domain-containing protein 4:Cytoplasmic do...  UBXN4:CD 1  Q92575
# 7595                     Interferon regulatory factor 6        IRF6  O14896
#
#      EntrezGeneID EntrezGeneSymbol Organism Units     Type Dilution
# 0            1415           CRYBB2    Human        Protein       20
# 1            5894             RAF1    Human        Protein       20
# 2            7592            ZNF41    Human        Protein      0.5
# 3            2002             ELK1    Human        Protein       20
# 4            2978           GUCA1A    Human        Protein       20
# ...           ...              ...      ...   ...      ...      ...
# 7591         9422           ZNF264    Human        Protein       20
# 7592          496            ATP4B    Human        Protein       20
# 7593         1854              DUT    Human        Protein       20
# 7594        23190            UBXN4    Human        Protein       20
# 7595         3664             IRF6    Human        Protein       20
#
# [7596 rows x 12 columns]

# %%
adat_path = r"./data/OH2024_014.adat"

# %%
plate_adat = somadata.read_adat(adat_path)
# Out:
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "SeqIdVersion"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')
# c:\Users\RoeeOrland\Documents\Streck-normalization\Roee_from_Gil\roee_gil_env\Lib\site-packages\somadata\io\adat\file.py:149: UserWarning: Adding empty values to column metadata: "Units"
#   warnings.warn(f'Adding empty values to column metadata: "{name}"')

# %%
plate_targets_df = plate_adat.columns.to_frame().reset_index(drop=True)

# %%
plate_targets_df
# Out:
#          SeqId SeqIdVersion    SomaId  \
# 0     10000-28               SL019233
# 1      10001-7               SL002564
# 2     10003-15               SL019245
# 3     10006-25               SL019228
# 4     10008-43               SL019234
# ...        ...          ...       ...
# 7591   9993-11               SL019212
# 7592  9994-217               SL019217
# 7593    9995-6               SL013164
# 7594   9997-12               SL026026
# 7595    9999-1               SL019231
#
#                                          TargetFullName      Target UniProt  \
# 0                                    Beta-crystallin B2       CRBB2  P43320
# 1     RAF proto-oncogene serine/threonine-protein ki...       c-Raf  P04049
# 2                                Zinc finger protein 41       ZNF41  P51814
# 3                   ETS domain-containing protein Elk-1        ELK1  P19419
# 4                 Guanylyl cyclase-activating protein 1       GUC1A  P43080
# ...                                                 ...         ...     ...
# 7591                            Zinc finger protein 264       ZN264  O43296
# 7592         Potassium-transporting ATPase subunit beta       ATP4B  P51164
# 7593  Deoxyuridine 5'-triphosphate nucleotidohydrola...         DUT  P33316
# 7594  UBX domain-containing protein 4:Cytoplasmic do...  UBXN4:CD 1  Q92575
# 7595                     Interferon regulatory factor 6        IRF6  O14896
#
#      EntrezGeneID EntrezGeneSymbol Organism Units     Type Dilution
# 0            1415           CRYBB2    Human        Protein       20
# 1            5894             RAF1    Human        Protein       20
# 2            7592            ZNF41    Human        Protein      0.5
# 3            2002             ELK1    Human        Protein       20
# 4            2978           GUCA1A    Human        Protein       20
# ...           ...              ...      ...   ...      ...      ...
# 7591         9422           ZNF264    Human        Protein       20
# 7592          496            ATP4B    Human        Protein       20
# 7593         1854              DUT    Human        Protein       20
# 7594        23190            UBXN4    Human        Protein       20
# 7595         3664             IRF6    Human        Protein       20
#
# [7596 rows x 12 columns]

# %%
plate_targets_df.iloc[-1, :]
# Out:
# SeqId                                       9999-1
# SeqIdVersion
# SomaId                                    SL019231
# TargetFullName      Interferon regulatory factor 6
# Target                                        IRF6
# UniProt                                     O14896
# EntrezGeneID                                  3664
# EntrezGeneSymbol                              IRF6
# Organism                                     Human
# Units
# Type                                       Protein
# Dilution                                        20
# Name: 7595, dtype: object

# %%
plate_adat[plate_adat.columns[1]]
# Out:
# PlateId     PlateRunDate  ScannerID   PlatePosition  SlideId       Subarray  SampleId    SampleType  PercentDilution  SampleMatrix  Barcode  Barcode2d  SampleName  SampleNotes  AliquotingNotes  SampleDescription  AssayNotes  TimePoint  ExtIdentifier       SsfExtId  SampleGroup  SiteId      SubjectID  CLI  RMA  StudyId     SampleNumber  Optional1             Optional2
# OH2024_014  2024-04-03    SG21378706  A1             258633804307  1         200169      Calibrator  20                             200169O                                                                                                 EXID67606365070184                         OH2024_014                       Control     1                                                       559.0
#                                       A10            258633804316  1         2132156351  Sample      20                                                                                                                                     EXID21815560894165                         OH2024_014                       OH2024_014  73            004-1136-0 VAMS       Trial              1379.3
#                                       A11            258633804292  1         2132281285  Sample      20                                                                                                                                     EXID20962582064384                         OH2024_014                       OH2024_014  81            GM9-XQ4-M             QC_NEG-040_V2.0     669.4
#                                       A12            258633804293  1         2132156350  Sample      20                                                                                                                                     EXID33468569274800                         OH2024_014                       OH2024_014  89            008-1707-0 VAMS       Trial              1367.8
#                                       A2             258633804308  1         2132154726  Sample      20                                                                                                                                     EXID04981399663517                         OH2024_014                       OH2024_014  9             041-0082-PD           Trial              1368.9
#                                                                                                                                                                                                                                                                                                                                                                                             ...
#                                       H5             258633804311  8         2132156382  Sample      20                                                                                                                                     EXID25666589185688                         OH2024_014                       OH2024_014  40            041-0063-PD VAMS      Trial              1182.0
#                                       H6             258633804312  8         2132154712  Sample      20                                                                                                                                     EXID04736535882111                         OH2024_014                       OH2024_014  48            ACSK381675-232729-01  PROPHET             732.7
#                                       H7             258633804313  8         2132155959  Sample      20                                                                                                                                     EXID96216315291953                         OH2024_014                       OH2024_014  56            FU9-YC6-H             QC_NEG-042_V2.0     601.8
#                                       H8             258633804314  8         2132156378  Sample      20                                                                                                                                     EXID39477712219730                         OH2024_014                       OH2024_014  64            001-1008-0 VAMS       Trial              1116.1
#                                       H9             258633804315  8         2132156335  Sample      20                                                                                                                                     EXID75126544409255                         OH2024_014                       OH2024_014  72            004-1110-0 VAMS       Trial              2589.8
# Name: (10001-7, , SL002564, RAF proto-oncogene serine/threonine-protein kinase, c-Raf, P04049, 5894, RAF1, Human, , Protein, 20), Length: 96, dtype: float64

# %%
plate_adat.index
# Out:
# MultiIndex([('OH2024_014', '2024-04-03', 'SG21378706',  'A1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'A10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'A11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'A12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'A9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'B10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'B11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'B12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'B9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'C10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'C11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'C12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'C9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'D10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'D11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'D12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'D9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'E10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'E11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'E12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'E9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'F10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'F11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'F12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'F9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'G10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'G11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'G12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'G9', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H1', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'H10', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'H11', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706', 'H12', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H2', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H3', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H4', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H5', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H6', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H7', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H8', ...),
#             ('OH2024_014', '2024-04-03', 'SG21378706',  'H9', ...)],
#            names=['PlateId', 'PlateRunDate', 'ScannerID', 'PlatePosition', 'SlideId', 'Subarray', 'SampleId', 'SampleType', 'PercentDilution', 'SampleMatrix', 'Barcode', 'Barcode2d', 'SampleName', 'SampleNotes', 'AliquotingNotes', 'SampleDescription', 'AssayNotes', 'TimePoint', 'ExtIdentifier', 'SsfExtId', 'SampleGroup', 'SiteId', 'SubjectID', 'CLI', 'RMA', 'StudyId', 'SampleNumber', 'Optional1', 'Optional2'])

# %%
df = plate_adat.reset_index()

# %%
df.head()
# Out:
# SeqId                PlateId PlateRunDate   ScannerID PlatePosition  \
# SeqIdVersion
# SomaId
# TargetFullName
# Target
# UniProt
# EntrezGeneID
# EntrezGeneSymbol
# Organism
# Units
# Type
# Dilution
# 0                 OH2024_014   2024-04-03  SG21378706            A1
# 1                 OH2024_014   2024-04-03  SG21378706           A10
# 2                 OH2024_014   2024-04-03  SG21378706           A11
# 3                 OH2024_014   2024-04-03  SG21378706           A12
# 4                 OH2024_014   2024-04-03  SG21378706            A2
#
# SeqId                  SlideId Subarray    SampleId  SampleType  \
# SeqIdVersion
# SomaId
# TargetFullName
# Target
# UniProt
# EntrezGeneID
# EntrezGeneSymbol
# Organism
# Units
# Type
# Dilution
# 0                 258633804307        1      200169  Calibrator
# 1                 258633804316        1  2132156351      Sample
# 2                 258633804292        1  2132281285      Sample
# 3                 258633804293        1  2132156350      Sample
# 4                 258633804308        1  2132154726      Sample
#
# SeqId            PercentDilution SampleMatrix  ...       9984-12  \
# SeqIdVersion                                   ...
# SomaId                                         ...      SL019205
# TargetFullName                                 ... Protein YIPF6
# Target                                         ...         YIPF6
# UniProt                                        ...        Q96EC8
# EntrezGeneID                                   ...        286451
# EntrezGeneSymbol                               ...         YIPF6
# Organism                                       ...         Human
# Units                                          ...
# Type                                           ...       Protein
# Dilution                                       ...            20
# 0                             20               ...        1202.0
# 1                             20               ...        1847.2
# 2                             20               ...        1337.1
# 3                             20               ...        2730.3
# 4                             20               ...        1307.8
#
# SeqId                   9986-14  \
# SeqIdVersion
# SomaId                 SL005356
# TargetFullName   Neuropeptide W
# Target           Neuropeptide W
# UniProt                  Q8N729
# EntrezGeneID             283869
# EntrezGeneSymbol            NPW
# Organism                  Human
# Units
# Type                    Protein
# Dilution                     20
# 0                        6165.7
# 1                        2517.0
# 2                        3449.5
# 3                        8589.5
# 4                        9598.7
#
# SeqId                                                                 9987-30  \
# SeqIdVersion
# SomaId                                                               SL025917
# TargetFullName   Leucine-rich repeat-containing protein 25:Cytoplasmic domain
# Target                                                               LRC25:CD
# UniProt                                                                Q8N386
# EntrezGeneID                                                           126364
# EntrezGeneSymbol                                                       LRRC25
# Organism                                                                Human
# Units
# Type                                                                  Protein
# Dilution                                                                   20
# 0                                                            1575.5
# 1                                                            1410.6
# 2                                                             905.3
# 3                                                            2400.0
# 4                                                            1022.8
#
# SeqId                                              9989-12          9991-112  \
# SeqIdVersion
# SomaId                                            SL019194          SL025845
# TargetFullName   Leucine-rich repeat-containing protein 24 EMILIN-3:region 2
# Target                                               LRC24    EMIL3:region 2
# UniProt                                             Q50LG9            Q9NT22
# EntrezGeneID                                        441381             90187
# EntrezGeneSymbol                                    LRRC24           EMILIN3
# Organism                                             Human             Human
# Units
# Type                                               Protein           Protein
# Dilution                                                20                20
# 0                                                    996.1            2730.1
# 1                                                   1430.1            1790.2
# 2                                                   1199.2             835.6
# 3                                                   1946.6            2494.4
# 4                                                   1017.3            1136.9
#
# SeqId                            9993-11  \
# SeqIdVersion
# SomaId                          SL019212
# TargetFullName   Zinc finger protein 264
# Target                             ZN264
# UniProt                           O43296
# EntrezGeneID                        9422
# EntrezGeneSymbol                  ZNF264
# Organism                           Human
# Units
# Type                             Protein
# Dilution                              20
# 0                                 2481.3
# 1                                 2788.3
# 2                                 2180.1
# 3                                 4253.0
# 4                                 2237.9
#
# SeqId                                              9994-217  \
# SeqIdVersion
# SomaId                                             SL019217
# TargetFullName   Potassium-transporting ATPase subunit beta
# Target                                                ATP4B
# UniProt                                              P51164
# EntrezGeneID                                            496
# EntrezGeneSymbol                                      ATP4B
# Organism                                              Human
# Units
# Type                                                Protein
# Dilution                                                 20
# 0                                                    3393.3
# 1                                                    5244.1
# 2                                                    3792.3
# 3                                                    6926.2
# 4                                                    4330.5
#
# SeqId                                                                     9995-6  \
# SeqIdVersion
# SomaId                                                                  SL013164
# TargetFullName   Deoxyuridine 5'-triphosphate nucleotidohydrolase, mitochondrial
# Target                                                                       DUT
# UniProt                                                                   P33316
# EntrezGeneID                                                                1854
# EntrezGeneSymbol                                                             DUT
# Organism                                                                   Human
# Units
# Type                                                                     Protein
# Dilution                                                                      20
# 0                                                            3888.4
# 1                                                           12829.6
# 2                                                            3082.4
# 3                                                            4267.3
# 4                                                            5915.0
#
# SeqId                                                         9997-12  \
# SeqIdVersion
# SomaId                                                       SL026026
# TargetFullName   UBX domain-containing protein 4:Cytoplasmic domain 1
# Target                                                     UBXN4:CD 1
# UniProt                                                        Q92575
# EntrezGeneID                                                    23190
# EntrezGeneSymbol                                                UBXN4
# Organism                                                        Human
# Units
# Type                                                          Protein
# Dilution                                                           20
# 0                                                           11088.8
# 1                                                           14249.6
# 2                                                           10598.7
# 3                                                            8419.4
# 4                                                           48394.6
#
# SeqId                                    9999-1
# SeqIdVersion
# SomaId                                 SL019231
# TargetFullName   Interferon regulatory factor 6
# Target                                     IRF6
# UniProt                                  O14896
# EntrezGeneID                               3664
# EntrezGeneSymbol                           IRF6
# Organism                                  Human
# Units
# Type                                    Protein
# Dilution                                     20
# 0                                        2580.8
# 1                                        9475.5
# 2                                        2447.9
# 3                                        5668.6
# 4                                       11510.8
#
# [5 rows x 7625 columns]

# %%
df.columns = ['_'.join(map(str, col)).strip('_') if isinstance(col, tuple) else col
              for col in df.columns]

# %%
df
# Out:
#        PlateId PlateRunDate   ScannerID PlatePosition       SlideId Subarray  \
# 0   OH2024_014   2024-04-03  SG21378706            A1  258633804307        1
# 1   OH2024_014   2024-04-03  SG21378706           A10  258633804316        1
# 2   OH2024_014   2024-04-03  SG21378706           A11  258633804292        1
# 3   OH2024_014   2024-04-03  SG21378706           A12  258633804293        1
# 4   OH2024_014   2024-04-03  SG21378706            A2  258633804308        1
# ..         ...          ...         ...           ...           ...      ...
# 91  OH2024_014   2024-04-03  SG21378706            H5  258633804311        8
# 92  OH2024_014   2024-04-03  SG21378706            H6  258633804312        8
# 93  OH2024_014   2024-04-03  SG21378706            H7  258633804313        8
# 94  OH2024_014   2024-04-03  SG21378706            H8  258633804314        8
# 95  OH2024_014   2024-04-03  SG21378706            H9  258633804315        8
#
#       SampleId  SampleType PercentDilution SampleMatrix  ...  \
# 0       200169  Calibrator              20               ...
# 1   2132156351      Sample              20               ...
# 2   2132281285      Sample              20               ...
# 3   2132156350      Sample              20               ...
# 4   2132154726      Sample              20               ...
# ..         ...         ...             ...          ...  ...
# 91  2132156382      Sample              20               ...
# 92  2132154712      Sample              20               ...
# 93  2132155959      Sample              20               ...
# 94  2132156378      Sample              20               ...
# 95  2132156335      Sample              20               ...
#
#    9984-12__SL019205_Protein YIPF6_YIPF6_Q96EC8_286451_YIPF6_Human__Protein_20  \
# 0                                              1202.0
# 1                                              1847.2
# 2                                              1337.1
# 3                                              2730.3
# 4                                              1307.8
# ..                                                ...
# 91                                             2710.3
# 92                                             1196.5
# 93                                             1581.2
# 94                                             2212.7
# 95                                             2493.6
#
#    9986-14__SL005356_Neuropeptide W_Neuropeptide W_Q8N729_283869_NPW_Human__Protein_20  \
# 0                                              6165.7
# 1                                              2517.0
# 2                                              3449.5
# 3                                              8589.5
# 4                                              9598.7
# ..                                                ...
# 91                                             7300.7
# 92                                             2208.9
# 93                                             6010.2
# 94                                             6402.6
# 95                                             3320.9
#
#    9987-30__SL025917_Leucine-rich repeat-containing protein 25:Cytoplasmic domain_LRC25:CD_Q8N386_126364_LRRC25_Human__Protein_20  \
# 0                                              1575.5
# 1                                              1410.6
# 2                                               905.3
# 3                                              2400.0
# 4                                              1022.8
# ..                                                ...
# 91                                             2397.1
# 92                                              850.0
# 93                                             1229.5
# 94                                             1850.6
# 95                                             2383.9
#
#    9989-12__SL019194_Leucine-rich repeat-containing protein 24_LRC24_Q50LG9_441381_LRRC24_Human__Protein_20  \
# 0                                               996.1
# 1                                              1430.1
# 2                                              1199.2
# 3                                              1946.6
# 4                                              1017.3
# ..                                                ...
# 91                                             1517.8
# 92                                              975.6
# 93                                             1517.1
# 94                                             1381.3
# 95                                             1554.9
#
#    9991-112__SL025845_EMILIN-3:region 2_EMIL3:region 2_Q9NT22_90187_EMILIN3_Human__Protein_20  \
# 0                                              2730.1
# 1                                              1790.2
# 2                                               835.6
# 3                                              2494.4
# 4                                              1136.9
# ..                                                ...
# 91                                             2670.2
# 92                                              836.2
# 93                                             1114.2
# 94                                             2571.1
# 95                                             2836.5
#
#    9993-11__SL019212_Zinc finger protein 264_ZN264_O43296_9422_ZNF264_Human__Protein_20  \
# 0                                              2481.3
# 1                                              2788.3
# 2                                              2180.1
# 3                                              4253.0
# 4                                              2237.9
# ..                                                ...
# 91                                             4342.0
# 92                                             1730.4
# 93                                             3645.5
# 94                                             3510.1
# 95                                             4243.7
#
#    9994-217__SL019217_Potassium-transporting ATPase subunit beta_ATP4B_P51164_496_ATP4B_Human__Protein_20  \
# 0                                              3393.3
# 1                                              5244.1
# 2                                              3792.3
# 3                                              6926.2
# 4                                              4330.5
# ..                                                ...
# 91                                             7147.8
# 92                                             2731.7
# 93                                             4195.8
# 94                                             6225.8
# 95                                             8921.5
#
#    9995-6__SL013164_Deoxyuridine 5'-triphosphate nucleotidohydrolase, mitochondrial_DUT_P33316_1854_DUT_Human__Protein_20  \
# 0                                              3888.4
# 1                                             12829.6
# 2                                              3082.4
# 3                                              4267.3
# 4                                              5915.0
# ..                                                ...
# 91                                             6816.5
# 92                                             2499.8
# 93                                            11113.5
# 94                                             6706.5
# 95                                            18352.1
#
#    9997-12__SL026026_UBX domain-containing protein 4:Cytoplasmic domain 1_UBXN4:CD 1_Q92575_23190_UBXN4_Human__Protein_20  \
# 0                                             11088.8
# 1                                             14249.6
# 2                                             10598.7
# 3                                              8419.4
# 4                                             48394.6
# ..                                                ...
# 91                                             9090.8
# 92                                            12729.7
# 93                                            30471.0
# 94                                             8943.7
# 95                                            37672.7
#
#    9999-1__SL019231_Interferon regulatory factor 6_IRF6_O14896_3664_IRF6_Human__Protein_20
# 0                                              2580.8
# 1                                              9475.5
# 2                                              2447.9
# 3                                              5668.6
# 4                                             11510.8
# ..                                                ...
# 91                                             6383.3
# 92                                             2337.8
# 93                                             3624.3
# 94                                             6304.5
# 95                                            18779.7
#
# [96 rows x 7625 columns]

# %%
df.columns = [column.split('__')[0] for column in df.columns]

# %%
df
# Out:
#        PlateId PlateRunDate   ScannerID PlatePosition       SlideId Subarray  \
# 0   OH2024_014   2024-04-03  SG21378706            A1  258633804307        1
# 1   OH2024_014   2024-04-03  SG21378706           A10  258633804316        1
# 2   OH2024_014   2024-04-03  SG21378706           A11  258633804292        1
# 3   OH2024_014   2024-04-03  SG21378706           A12  258633804293        1
# 4   OH2024_014   2024-04-03  SG21378706            A2  258633804308        1
# ..         ...          ...         ...           ...           ...      ...
# 91  OH2024_014   2024-04-03  SG21378706            H5  258633804311        8
# 92  OH2024_014   2024-04-03  SG21378706            H6  258633804312        8
# 93  OH2024_014   2024-04-03  SG21378706            H7  258633804313        8
# 94  OH2024_014   2024-04-03  SG21378706            H8  258633804314        8
# 95  OH2024_014   2024-04-03  SG21378706            H9  258633804315        8
#
#       SampleId  SampleType PercentDilution SampleMatrix  ... 9984-12 9986-14  \
# 0       200169  Calibrator              20               ...  1202.0  6165.7
# 1   2132156351      Sample              20               ...  1847.2  2517.0
# 2   2132281285      Sample              20               ...  1337.1  3449.5
# 3   2132156350      Sample              20               ...  2730.3  8589.5
# 4   2132154726      Sample              20               ...  1307.8  9598.7
# ..         ...         ...             ...          ...  ...     ...     ...
# 91  2132156382      Sample              20               ...  2710.3  7300.7
# 92  2132154712      Sample              20               ...  1196.5  2208.9
# 93  2132155959      Sample              20               ...  1581.2  6010.2
# 94  2132156378      Sample              20               ...  2212.7  6402.6
# 95  2132156335      Sample              20               ...  2493.6  3320.9
#
#    9987-30 9989-12 9991-112 9993-11 9994-217   9995-6  9997-12   9999-1
# 0   1575.5   996.1   2730.1  2481.3   3393.3   3888.4  11088.8   2580.8
# 1   1410.6  1430.1   1790.2  2788.3   5244.1  12829.6  14249.6   9475.5
# 2    905.3  1199.2    835.6  2180.1   3792.3   3082.4  10598.7   2447.9
# 3   2400.0  1946.6   2494.4  4253.0   6926.2   4267.3   8419.4   5668.6
# 4   1022.8  1017.3   1136.9  2237.9   4330.5   5915.0  48394.6  11510.8
# ..     ...     ...      ...     ...      ...      ...      ...      ...
# 91  2397.1  1517.8   2670.2  4342.0   7147.8   6816.5   9090.8   6383.3
# 92   850.0   975.6    836.2  1730.4   2731.7   2499.8  12729.7   2337.8
# 93  1229.5  1517.1   1114.2  3645.5   4195.8  11113.5  30471.0   3624.3
# 94  1850.6  1381.3   2571.1  3510.1   6225.8   6706.5   8943.7   6304.5
# 95  2383.9  1554.9   2836.5  4243.7   8921.5  18352.1  37672.7  18779.7
#
# [96 rows x 7625 columns]

# %%
type(df)
# Out:
# somadata.adat.Adat

# %%
plate_targets_df
# Out:
#          SeqId SeqIdVersion    SomaId  \
# 0     10000-28               SL019233
# 1      10001-7               SL002564
# 2     10003-15               SL019245
# 3     10006-25               SL019228
# 4     10008-43               SL019234
# ...        ...          ...       ...
# 7591   9993-11               SL019212
# 7592  9994-217               SL019217
# 7593    9995-6               SL013164
# 7594   9997-12               SL026026
# 7595    9999-1               SL019231
#
#                                          TargetFullName      Target UniProt  \
# 0                                    Beta-crystallin B2       CRBB2  P43320
# 1     RAF proto-oncogene serine/threonine-protein ki...       c-Raf  P04049
# 2                                Zinc finger protein 41       ZNF41  P51814
# 3                   ETS domain-containing protein Elk-1        ELK1  P19419
# 4                 Guanylyl cyclase-activating protein 1       GUC1A  P43080
# ...                                                 ...         ...     ...
# 7591                            Zinc finger protein 264       ZN264  O43296
# 7592         Potassium-transporting ATPase subunit beta       ATP4B  P51164
# 7593  Deoxyuridine 5'-triphosphate nucleotidohydrola...         DUT  P33316
# 7594  UBX domain-containing protein 4:Cytoplasmic do...  UBXN4:CD 1  Q92575
# 7595                     Interferon regulatory factor 6        IRF6  O14896
#
#      EntrezGeneID EntrezGeneSymbol Organism Units     Type Dilution
# 0            1415           CRYBB2    Human        Protein       20
# 1            5894             RAF1    Human        Protein       20
# 2            7592            ZNF41    Human        Protein      0.5
# 3            2002             ELK1    Human        Protein       20
# 4            2978           GUCA1A    Human        Protein       20
# ...           ...              ...      ...   ...      ...      ...
# 7591         9422           ZNF264    Human        Protein       20
# 7592          496            ATP4B    Human        Protein       20
# 7593         1854              DUT    Human        Protein       20
# 7594        23190            UBXN4    Human        Protein       20
# 7595         3664             IRF6    Human        Protein       20
#
# [7596 rows x 12 columns]

# %%
plate_targets_df['Dilution'].value_counts()
# Out:
# Dilution
# 20       6257
# 0.5      1131
# 0.005     196
# 0          12
# Name: count, dtype: int64

# %%
plate_targets_df.shape
# Out:
# (7596, 12)

# %%
plate_targets_df.head()
# Out:
#       SeqId SeqIdVersion    SomaId  \
# 0  10000-28               SL019233
# 1   10001-7               SL002564
# 2  10003-15               SL019245
# 3  10006-25               SL019228
# 4  10008-43               SL019234
#
#                                       TargetFullName Target UniProt  \
# 0                                 Beta-crystallin B2  CRBB2  P43320
# 1  RAF proto-oncogene serine/threonine-protein ki...  c-Raf  P04049
# 2                             Zinc finger protein 41  ZNF41  P51814
# 3                ETS domain-containing protein Elk-1   ELK1  P19419
# 4              Guanylyl cyclase-activating protein 1  GUC1A  P43080
#
#   EntrezGeneID EntrezGeneSymbol Organism Units     Type Dilution
# 0         1415           CRYBB2    Human        Protein       20
# 1         5894             RAF1    Human        Protein       20
# 2         7592            ZNF41    Human        Protein      0.5
# 3         2002             ELK1    Human        Protein       20
# 4         2978           GUCA1A    Human        Protein       20

# %%
plate_targets_df[['SeqId', 'Dilution']]
# Out:
#          SeqId Dilution
# 0     10000-28       20
# 1      10001-7       20
# 2     10003-15      0.5
# 3     10006-25       20
# 4     10008-43       20
# ...        ...      ...
# 7591   9993-11       20
# 7592  9994-217       20
# 7593    9995-6       20
# 7594   9997-12       20
# 7595    9999-1       20
#
# [7596 rows x 2 columns]

# %%
dilution_dict = {row['SeqId']: row['Dilution'] for _, row in plate_targets_df.iterrows()}

# %%
set(dilution_dict.values())
# Out:
# {'0', '0.005', '0.5', '20'}

# %%
dfs = {name: group for name, group in plate_targets_df.groupby('Dilution')}

# %%
dfs.keys()
# Out:
# dict_keys(['0', '0.005', '0.5', '20'])

# %%
dilution_005_df = dfs['0.005']
diluttion_05_df = dfs['0.5']
dilution_20_df = dfs['20']

# %%
dilution_005_df
# Out:
#           SeqId SeqIdVersion    SomaId  \
# 73      10391-1               SL006803
# 92     10445-20               SL004747
# 213     10666-7               SL012791
# 274   10819-108               SL004461
# 343     11089-7               SL000459
# ...         ...          ...       ...
# 7243     9269-7               SL000303
# 7266     9312-8               SL005396
# 7275    9326-33               SL004711
# 7290     9348-1               SL010648
# 7337   9449-150               SL015989
#
#                                          TargetFullName  \
# 73                       Angiopoietin-related protein 3
# 92                                     Apolipoprotein M
# 213   N-acetylglucosamine-1-phosphotransferase subun...
# 274                                           Fibulin-1
# 343                                    Immunoglobulin A
# ...                                                 ...
# 7243                                        Biotinidase
# 7266                          Zinc-alpha-2-glycoprotein
# 7275       Inter-alpha-trypsin inhibitor heavy chain H2
# 7290           Complement C1r subcomponent-like protein
# 7337                    C4b-binding protein alpha chain
#
#                                Target        UniProt EntrezGeneID  \
# 73                              ANGL3         Q9Y5C1        27329
# 92                               ApoM         O95445        55937
# 213                             GNPTG         Q9UJJ9        84572
# 274                         fibulin 1         P23142         2192
# 343                               IgA  P01877|P01876    3494|3493
# ...                               ...            ...          ...
# 7243                      Biotinidase         P43251          686
# 7266                            AZGP1         P25311          563
# 7275               ITI heavy chain H2         P19823         3698
# 7290                            C1RL1         Q9NZP8        51279
# 7337  C4b-binding protein alpha chain         P04003          722
#
#      EntrezGeneSymbol Organism Units     Type Dilution
# 73            ANGPTL3    Human        Protein    0.005
# 92               APOM    Human        Protein    0.005
# 213             GNPTG    Human        Protein    0.005
# 274             FBLN1    Human        Protein    0.005
# 343       IGHA2|IGHA1    Human        Protein    0.005
# ...               ...      ...   ...      ...      ...
# 7243              BTD    Human        Protein    0.005
# 7266            AZGP1    Human        Protein    0.005
# 7275            ITIH2    Human        Protein    0.005
# 7290             C1RL    Human        Protein    0.005
# 7337            C4BPA    Human        Protein    0.005
#
# [196 rows x 12 columns]
